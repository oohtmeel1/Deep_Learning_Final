# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib as plt
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import numpy as np 
import pandas as pd 
import re
from tqdm import tqdm
from keras.models import Sequential
from keras.layers import Embedding,LSTM,Dense,SpatialDropout1D
from keras.layers import Conv1D

from keras.initializers import Constant
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import (BatchNormalization,Dense,
                          TimeDistributed, Dropout, Bidirectional,Flatten, GlobalMaxPool1D)
from keras_preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from sklearn.utils import shuffle
from keras.utils import to_categorical
import os
from glob import glob 
import numpy as np
import os
import PIL.Image
import tensorflow as tf
import pathlib
import numpy as np
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from PIL import Image
from sklearn.model_selection import train_test_split
from imutils import paths
import numpy as np
import argparse
import imutils
import cv2
import os
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from glob import glob 
pd.set_option('display.max_colwidth', 255)
# Out:
# WARNING:tensorflow:From c:\gitfiles\Lib\site-packages\tensorflow\python\ops\distributions\distribution.py:259: ReparameterizationType.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From c:\gitfiles\Lib\site-packages\tensorflow\python\ops\distributions\bernoulli.py:165: RegisterKL.__init__ (from tensorflow.python.ops.distributions.kullback_leibler) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.

# %%
model1_2=pd.read_csv('model_1_1stats',index_col=[0])
model2_2=pd.read_csv('model_2_2stats',index_col=[0])
model3_2=pd.read_csv('model_3_3stats',index_col=[0])
model4_2=pd.read_csv('model_4_4stats',index_col=[0])
model5_2=pd.read_csv('model_5_5stats',index_col=[0])
model6_2=pd.read_csv('model_6_6stats',index_col=[0])
model7_2=pd.read_csv('model_7_7stats',index_col=[0])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
plt.plot(model6[model6.columns[2:3]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Accuracy of sixth model ')
ax.grid()

# %%
model7_2
# Out:
#     model7_val_loss  model7_val_accuracy  model_7_accuracy  model_7_loss
# 0          0.657423             0.614542          0.560484      0.700649
# 1          0.643755             0.670811          0.657559      0.628745
# 2          0.657358             0.633509          0.707932      0.577140
# 3          0.560360             0.713382          0.736820      0.547156
# 4          0.556694             0.718440          0.731644      0.552522
# 5          0.553775             0.720548          0.733871      0.549672
# 6          0.562057             0.712961          0.734533      0.545326
# 7          0.544222             0.727924          0.738926      0.545068
# 8          0.555048             0.715912          0.732005      0.549905
# 9          0.554659             0.717808          0.734834      0.549857
# 10         0.556603             0.720126          0.735255      0.544881

# %%
fig, ax = plt.subplots()
plt.plot(model1_2[model1_2.columns[0:1]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation loss of first model ')
ax.grid()

fig, ax = plt.subplots()
plt.plot(model1_2[model1_2.columns[1:2]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation Accuracy of first model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model1_2[model1_2.columns[2:3]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Accuracy of first model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model1_2[model1_2.columns[3:4]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='loss of first model ')
ax.grid()

# %%
fig, ax = plt.subplots()
plt.plot(model2_2[model2_2.columns[0:1]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation loss of second model ')
ax.grid()


fig, ax = plt.subplots()
plt.plot(model2_2[model2_2.columns[1:2]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation Accuracy of second model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model2_2[model2_2.columns[2:3]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Accuracy of second model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model2_2[model2_2.columns[3:4]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='loss of second model ')
ax.grid()

# %%
fig, ax = plt.subplots()
plt.plot(model3_2[model3_2.columns[0:1]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation loss of third model ')
ax.grid()


fig, ax = plt.subplots()
plt.plot(model3_2[model3_2.columns[1:2]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation Accuracy of third model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model3_2[model3_2.columns[2:3]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Accuracy of third model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model3_2[model3_2.columns[3:4]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='loss of third model ')
ax.grid()

# %%
fig, ax = plt.subplots()
plt.plot(model4_2[model4_2.columns[0:1]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation loss of fourth model ')
ax.grid()


fig, ax = plt.subplots()
plt.plot(model4_2[model4_2.columns[1:2]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation Accuracy of fourth model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model4_2[model4_2.columns[2:3]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Accuracy of fourth model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model4_2[model4_2.columns[3:4]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='loss of fourth model ')
ax.grid()

# %%
fig, ax = plt.subplots()
plt.plot(model5_2[model5_2.columns[0:1]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation loss of fifth model ')
ax.grid()


fig, ax = plt.subplots()
plt.plot(model5_2[model5_2.columns[1:2]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation Accuracy of fifth model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model5_2[model5_2.columns[2:3]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Accuracy of fifth model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model5_2[model5_2.columns[3:4]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='loss of fifth model ')
ax.grid()

# %%
fig, ax = plt.subplots()
plt.plot(model6_2[model6_2.columns[0:1]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation loss of sixth model ')
ax.grid()


fig, ax = plt.subplots()
plt.plot(model6_2[model6_2.columns[1:2]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation Accuracy of sixth model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model6_2[model6_2.columns[2:3]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Accuracy of sixth model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model6_2[model6_2.columns[3:4]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='loss of sixth model ')
ax.grid()

# %%
fig, ax = plt.subplots()
plt.plot(model7_2[model7_2.columns[0:1]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation loss of seventh model ')
ax.grid()


fig, ax = plt.subplots()
plt.plot(model7_2[model7_2.columns[1:2]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Validation Accuracy of seventh model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model7_2[model7_2.columns[2:3]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='Accuracy of seventh model ')
ax.grid()
fig, ax = plt.subplots()
plt.plot(model7_2[model7_2.columns[3:4]])
ax.set(xlabel='Epoch', ylabel='Accuracy',
       title='loss of seventh model ')
ax.grid()

# %%
model1_s=pd.read_csv('report_table1',index_col=[0])
model2_s=pd.read_csv('report_table2',index_col=[0])
model3_s=pd.read_csv('report_table3',index_col=[0])
model4_s=pd.read_csv('report_table4',index_col=[0])
model5_s=pd.read_csv('report_table5',index_col=[0])
model6_s=pd.read_csv('report_table6',index_col=[0])
model7_s=pd.read_csv('report_table7',index_col=[0])

# %%
# Out:
#                   0
# precision  0.795964

# %%
model4_s
# Out:
#                      0            1  accuracy    macro avg  weighted avg
# precision     0.795199     0.880077  0.832277     0.837638      0.837620
# recall        0.895270     0.769231  0.832277     0.832251      0.832277
# f1-score      0.842273     0.820929  0.832277     0.831601      0.831605
# support    1184.000000  1183.000000  0.832277  2367.000000   2367.000000

# %%
sns.heatmap(pd.DataFrame(model1_s).iloc[0:3, 0:2], annot=True)
plt.title("Model 1")
# Out:
# Text(0.5, 1.0, 'Model 1')

# %%
sns.heatmap(pd.DataFrame(model2_s).iloc[0:3, 0:2], annot=True)
plt.title("Model 2")
# Out:
# Text(0.5, 1.0, 'Model 2')

# %%
sns.heatmap(pd.DataFrame(model3_s).iloc[0:3, 0:2], annot=True)
plt.title("Model 3")
# Out:
# Text(0.5, 1.0, 'Model 3')

# %%
sns.heatmap(pd.DataFrame(model4_s).iloc[0:3, 0:2], annot=True)
plt.title("Model 4")
# Out:
# Text(0.5, 1.0, 'Model 4')

# %%
sns.heatmap(pd.DataFrame(model5_s).iloc[0:3, 0:2], annot=True)
plt.title("Model 5")
# Out:
# Text(0.5, 1.0, 'Model 5')

# %%
sns.heatmap(pd.DataFrame(model6_s).iloc[0:3, 0:2], annot=True)
plt.title("Model 6")
# Out:
# Text(0.5, 1.0, 'Model 6')

# %%
sns.heatmap(pd.DataFrame(model7_s).iloc[0:3, 0:2], annot=True)
plt.title("Model 7")
# Out:
# Text(0.5, 1.0, 'Model 7')

# %%
model1_s
# Out:
#                      0            1  accuracy    macro avg  weighted avg
# precision     0.785047     0.837488  0.809041     0.811268      0.811257
# recall        0.851351     0.766695  0.809041     0.809023      0.809041
# f1-score      0.816856     0.800530  0.809041     0.808693      0.808696
# support    1184.000000  1183.000000  0.809041  2367.000000   2367.000000

# %%
precision1=model1_s.iloc[0:1,0:1]
precision2=model2_s.iloc[0:1,0:1]
precision3=model3_s.iloc[0:1,0:1]
precision4=model4_s.iloc[0:1,0:1]
precision5=model5_s.iloc[0:1,0:1]
precision6=model6_s.iloc[0:1,0:1]
precision7=model7_s.iloc[0:1,0:1]

# %%
precision1
# Out:
#                   0
# precision  0.785047

# %%
result = pd.concat([precision1, precision2,precision3,precision4,precision5,precision6,precision7], axis=1)

# %%
resulting = result.rename(columns={0: "a", 0: "c"})

# %%
resulting=result.T

# %%
names = ['model1','model2','model3','model4','model5','model6','model7']

# %%
ax=resulting.plot(kind='bar')
ax.set_xlabel("model number")
ax.set_ylabel("precision score")
plt.xticks((0, 1, 2, 3, 4, 5, 6), ('model1','model2','model3','model4','model5','model6','model7'))
# Out:
# ([<matplotlib.axis.XTick at 0x246ca2f9150>,
# ...
#  [Text(0, 0, 'model1'),
#   Text(1, 0, 'model2'),
#   Text(2, 0, 'model3'),
#   Text(3, 0, 'model4'),
#   Text(4, 0, 'model5'),
#   Text(5, 0, 'model6'),
#   Text(6, 0, 'model7')])

# %%
precision1_=model1_s.iloc[0:1,1:2]

# %%
model1_s
# Out:
#                      0            1  accuracy    macro avg  weighted avg
# precision     0.785047     0.837488  0.809041     0.811268      0.811257
# recall        0.851351     0.766695  0.809041     0.809023      0.809041
# f1-score      0.816856     0.800530  0.809041     0.808693      0.808696
# support    1184.000000  1183.000000  0.809041  2367.000000   2367.000000

# %%
f1_score1_
# Out:
#                  0        1
# f1-score  0.816856  0.80053

# %%
precision1_=model1_s.iloc[0:1,1:2]
precision2_=model2_s.iloc[0:1,1:2]
precision3_=model3_s.iloc[0:1,1:2]
precision4_=model4_s.iloc[0:1,1:2]
precision5_=model5_s.iloc[0:1,1:2]
precision6_=model6_s.iloc[0:1,1:2]
precision7_=model7_s.iloc[0:1,1:2]

# %%
import numpy as ny
import matplotlib.pyplot as matplot

# %%
result_ = pd.concat([precision1_, precision2_,precision3_,precision4_,precision5_,precision6_,precision7_], axis=1)
result_T =result_.T.reset_index(drop=True)

# %%
resulting1 =resulting.reset_index(drop=True)

# %%
data = pd.concat([result_T,resulting1], axis=1)

# %%
data['difference']=data[0]
# Out:
#    precision  precision
# 0   0.837488   0.785047
# 1   0.809932   0.802335
# 2   0.884354   0.795964
# 3   0.880077   0.795199
# 4   0.886873   0.753846
# 5   0.849673   0.721877
# 6   0.860304   0.658759

# %%
fig, ax = plt.subplots()
data.plot(kind='bar',stacked=False,title ="Overall Precision")

plt.xticks((0, 1, 2, 3, 4, 5, 6), ('model1','model2','model3','model4','model5','model6','model7'))
# Out:
# ([<matplotlib.axis.XTick at 0x246cea56610>,
# ...
#  [Text(0, 0, 'model1'),
#   Text(1, 0, 'model2'),
#   Text(2, 0, 'model3'),
#   Text(3, 0, 'model4'),
#   Text(4, 0, 'model5'),
#   Text(5, 0, 'model6'),
#   Text(6, 0, 'model7')])

# %%
plt.bar(names, result, color='r')
plt.bar(names, result_, bottom=result, color='b')
plt.show()

# %%
recall1=model1_s.iloc[1:2,0:2]
recall2=model2_s.iloc[1:2,0:2]
recall3=model3_s.iloc[1:2,0:2]
recall4=model4_s.iloc[1:2,0:2]
recall5=model5_s.iloc[1:2,0:2]
recall6=model6_s.iloc[1:2,0:2]
recall7=model7_s.iloc[1:2,0:2]

# %%
result_Re = pd.concat([recall1, recall2,recall3,recall4,recall5,recall6,recall7], axis=0).reset_index(drop=True)

# %%
result_Re
# Out:
#           0         1
# 0  0.851351  0.766695
# 1  0.812500  0.799662
# 2  0.899493  0.769231
# 3  0.895270  0.769231
# 4  0.910473  0.702451
# 5  0.883446  0.659341
# 6  0.914696  0.525782

# %%
fig, ax = plt.subplots()
result_Re.plot(kind='bar',stacked=False,title ="Overall Recall")

plt.xticks((0, 1, 2, 3, 4, 5, 6), ('model1','model2','model3','model4','model5','model6','model7'))
# Out:
# ([<matplotlib.axis.XTick at 0x246ced41d10>,
# ...
#  [Text(0, 0, 'model1'),
#   Text(1, 0, 'model2'),
#   Text(2, 0, 'model3'),
#   Text(3, 0, 'model4'),
#   Text(4, 0, 'model5'),
#   Text(5, 0, 'model6'),
#   Text(6, 0, 'model7')])

# %%
f1_score1_=model1_s.iloc[2:3,0:2]
f1_score2_=model2_s.iloc[2:3,0:2]
f1_score3_=model3_s.iloc[2:3,0:2]
f1_score4_=model4_s.iloc[2:3,0:2]
f1_score5_=model5_s.iloc[2:3,0:2]
f1_score6_=model6_s.iloc[2:3,0:2]
f1_score7_=model7_s.iloc[2:3,0:2]

# %%
result_f1 = pd.concat([f1_score1_, f1_score2_,f1_score3_,f1_score4_,f1_score5_,f1_score6_,f1_score7_], axis=0).reset_index(drop=True)

# %%
fig, ax = plt.subplots()
result_f1.plot(kind='bar',stacked=False,title ="F1 Score")

plt.xticks((0, 1, 2, 3, 4, 5, 6), ('model1','model2','model3','model4','model5','model6','model7'))
# Out:
# ([<matplotlib.axis.XTick at 0x246cecf78d0>,
# ...
#  [Text(0, 0, 'model1'),
#   Text(1, 0, 'model2'),
#   Text(2, 0, 'model3'),
#   Text(3, 0, 'model4'),
#   Text(4, 0, 'model5'),
#   Text(5, 0, 'model6'),
#   Text(6, 0, 'model7')])

# %%
print(f1_score1_.max())
# Out:
# 0    0.816856
# 1    0.800530
# dtype: float64

# %%
max = data.max()

# %%
print(max)
# Out:
# precision    0.886873
# precision    0.802335
# dtype: float64

# %%
maxValueIndex = data.idxmax()

# %%
maxValueIndex
# Out:
# precision    4
# precision    1
# dtype: int64

# %%
maxValueIndex1 = result_Re.idxmax()

# %%
maxValueIndex1
# Out:
# 0    6
# 1    1
# dtype: int64

# %%
maxValueIndex2 = result_f1.idxmax()

# %%
maxValueIndex2
# Out:
# 0    2
# 1    2
# dtype: int64

# %%
precision111_=model1_s.iloc[0:1,2:3]

# %%
precision111_
# Out:
#            accuracy
# precision  0.809041

# %%
accuracy1_=model1_s.iloc[0:1,2:3]
accuracy2_=model2_s.iloc[0:1,2:3]
accuracy3_=model3_s.iloc[0:1,2:3]
accuracy4_=model4_s.iloc[0:1,2:3]
accuracy5_=model5_s.iloc[0:1,2:3]
accuracy6_=model6_s.iloc[0:1,2:3]
accuracy7_=model7_s.iloc[0:1,2:3]

# %%
accuracy_11 = pd.concat([accuracy1_, accuracy2_,accuracy3_,accuracy4_,accuracy5_,accuracy6_,accuracy7_], axis=0).reset_index(drop=True)

# %%
accuracy_11
# Out:
#           0         1
# 0  0.816856  0.800530
# 1  0.807386  0.804764
# 2  0.844568  0.822785
# 3  0.842273  0.820929
# 4  0.824790  0.783962
# 5  0.794531  0.742504
# 6  0.765912  0.652676

# %%
accuracy_11.plot(kind='bar',stacked=False,title ="overall_accuracy")

plt.xticks((0, 1, 2, 3, 4, 5, 6), ('model1','model2','model3','model4','model5','model6','model7'))
# Out:
# ([<matplotlib.axis.XTick at 0x246cefc3d50>,
# ...
#  [Text(0, 0, 'model1'),
#   Text(1, 0, 'model2'),
#   Text(2, 0, 'model3'),
#   Text(3, 0, 'model4'),
#   Text(4, 0, 'model5'),
#   Text(5, 0, 'model6'),
#   Text(6, 0, 'model7')])
